# %% [markdown]
# ## Homework 7 Phillips Curve
# ### Yue Yu
# ### Question 3 Reproduce graph
#
# Try to reproduce the three charts in figure 1 of the paper. If your charts don't match, check if there's a problem in the way you defined or aligned variables, but don't expect to achieve exact matches.
#
# Change in Inflation vs. Unemployment Gap
# Unemployment Gap $=$ civilian unemployment rate - assumed NAIRU of 6%

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
data1=pd.read_excel('Phillips.xls',sheetname = 'cleaned',header=0)
data1
# Out:
#     DATE    GDPDEF   COMPNFB  CPILFESL  UNRATE
# 0   1980  1.005800  1.111800  0.758300  7.1750
# 1   1981 -1.093400 -2.597000 -2.382400  7.6167
# 2   1982 -3.097000 -1.657400 -4.721000  9.7083
# 3   1983 -1.809300 -2.851800  0.201800  9.6000
# 4   1984  0.185600  0.827300  0.171600  7.5083
# 5   1985 -0.711500  1.146700 -0.580000  7.1917
# 6   1986 -0.962200 -0.421300 -0.518200  7.0000
# 7   1987  1.050300 -1.798600  0.369200  6.1750
# 8   1988  0.935900  1.540500  0.479200  5.4917
# 9   1989 -0.268600 -1.882500 -0.198600  5.2583
# 10  1990  0.251500  2.949800  0.837600  5.6167
# 11  1991 -0.710900 -0.969900 -0.878700  6.8500
# 12  1992 -0.941000  0.189400 -0.980300  7.4917
# 13  1993  0.147100 -4.443100 -0.237400  6.9083
# 14  1994 -0.218549  0.231527 -0.535553  6.1000

# %%
plt.ylim(-6,6)
plt.axhline(y=0, color='black',linestyle='-')
plt.plot(data1['DATE'],data1['UNRATE']-6,dashes=[5, 2])
plt.plot(data1['DATE'],data1['GDPDEF'],'-o')
plt.xlabel('Date')
plt.title('GDP deflator vs. Unemployment gap')
plt.legend()
plt.show()

# %%
plt.ylim(-6,6)
plt.axhline(y=0, color='black',linestyle='-')
plt.plot(data1['DATE'],data1['UNRATE']-6,dashes=[5, 2])
plt.plot(data1['DATE'],data1['COMPNFB'],'-o')
plt.xlabel('Date')
plt.title('Total Compensation vs. Unemployment gap')
plt.legend()
plt.show()

# %%
plt.ylim(-6,6)
plt.axhline(y=0, color='black',linestyle='-')
plt.plot(data1['DATE'],data1['UNRATE']-6,dashes=[5, 2])
plt.plot(data1['DATE'],data1['CPILFESL'],'-o')
plt.xlabel('Date')
plt.title('Core CPI vs. Unemployment gap')
plt.legend()
plt.show()

# %% [markdown]
# ### Question 4
# ##### Question
# The author wants to make the point that the unemployment gap (positive when unemployment is higher that its natural level, negative when it is below its natural level) is approximately equal to the change in inflation rate but with opposite sign. Does figure 1 support that point? Does your reconstruction of figure 1 support that point?
# ##### Answer
# Figure 1 roughly supports the point. The roots of unemployment gap is approximately the same with the roots of other inflation function(the two function intersect at x axis)
#
# The new produced figure roughly have the same function except for total compensation one.

# %% [markdown]
# ### Question 5
# ##### Question
# Now do the same three charts from 1995 to 2018. Do these charts support the author's point?

# %%
data2=pd.read_excel('Phillips.xls',sheetname = 'cleaned2',header=0)
data2
# Out:
#     DATE    GDPDEF   COMPNFB  CPILFESL    UNRATE
# 0   1995 -0.081158  1.775764  0.428961  5.591667
# 1   1996 -0.237863  0.582311 -0.385987  5.408333
# 2   1997 -0.197685  1.518380 -0.358397  4.941667
# 3   1998 -0.472803  0.258677  0.179385  4.500000
# 4   1999  0.531348 -0.067140 -0.560393  4.216667
# 5   2000  0.766198  1.203103  0.678672  3.966667
# 6   2001 -0.436610 -2.552551  0.203267  4.741667
# 7   2002 -0.232781 -1.630143 -0.801136  5.783333
# 8   2003  0.165701  3.149620 -0.858698  5.991667
# 9   2004  1.102975 -1.282175  1.154741  5.541667
# 10  2005  0.216892 -0.791850 -0.147670  5.083333
# 11  2006 -0.597744  0.807607  0.487714  4.608333
# 12  2007 -0.061356 -0.082901 -0.174122  4.616667
# 13  2008 -0.579720 -0.873265 -0.659854  5.800000
# 14  2009 -1.674837 -1.955003  0.059979  9.283333
# 15  2010  1.282180  0.305028 -1.148741  9.608333
# 16  2011  0.420925 -0.821698  1.593292  8.933333
# 17  2012  0.054288  5.073896 -0.369971  8.075000
# ...

# %%
plt.ylim(-6,6)
plt.axhline(y=0, color='black',linestyle='-')
plt.plot(data2['DATE'],data2['UNRATE']-6,dashes=[5, 2])
plt.plot(data2['DATE'],data2['GDPDEF'],'-o')
plt.xlabel('Date')
plt.title('GDP deflator vs. Unemployment gap')
plt.legend()
plt.show()

# %%
plt.ylim(-6,6)
plt.axhline(y=0, color='black',linestyle='-')
plt.plot(data2['DATE'],data2['UNRATE']-6,dashes=[5, 2])
plt.plot(data2['DATE'],data2['COMPNFB'],'-o')
plt.xlabel('Date')
plt.title('Total Compensation vs. Unemployment gap')
plt.legend()
plt.show()

# %%
plt.ylim(-6,6)
plt.axhline(y=0, color='black',linestyle='-')
plt.plot(data2['DATE'],data2['UNRATE']-6,dashes=[5, 2])
plt.plot(data2['DATE'],data2['CPILFESL'],'-o')
plt.xlabel('Date')
plt.title('Core CPI vs. Unemployment gap')
plt.legend()
plt.show()

# %% [markdown]
# ##### Answer
# I don't think it supports the argument in the table, the inflation rate becomes more volatile than unemployment rate. And there are several time periods where there exist high unemployment rate and high inflation rate at the same time.
#
# (The graph of GDP deflator is sort of supportive of the argument)

# %% [markdown]
# ### Question 6
# ##### Question
# Next recreate the regression in table 1 of the paper (just the first regressions, not 1a, 1b or 1c). What do you think of this regression? Are the results reliable? What are they telling you? Do they support the author's contention that low unemployment leads to higher inflation? How about the contention that independent of the level of inflation, decreasing unemployment leads to higher inflation? Divide the constant term by the sum of the two unemployment coefficients. Is this a good way to estimate the “non-accelerating-inflation rate of unemployment” or NAIRU?

# %%
import statsmodels.api as sm
data3 = pd.read_excel('Phillips.xls',sheetname = 'Regression1',header=0)
varlist = data3.columns.values
y=data3[varlist[0]]
x=data3[varlist[1:]]
x = sm.add_constant(x)
model = sm.OLS(y, x).fit() 
predictions = model.predict(x)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      t   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     45.65
# Date:                Tue, 09 Apr 2019   Prob (F-statistic):           4.27e-42
# Time:                        18:21:38   Log-Likelihood:                -2.6656
# No. Observations:                 135   AIC:                             37.33
# Df Residuals:                     119   BIC:                             83.82
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1929      0.123      1.566      0.120      -0.051       0.437
# ...

# %% [markdown]
# ### Question 7
# ##### Question
# Now recreate the regression using data from 1994Q1 to the present. Do the results differ from the values in question 6?

# %%
data4 = pd.read_excel('Phillips.xls',sheetname = 'Regression2prep',header=0)
varlist2 = data4.columns.values
p = data4[varlist2[0]]
q = data4[varlist2[1:]]
q = sm.add_constant(q)
model2 = sm.OLS(p, q).fit() 
predictions2 = model2.predict(q)
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      t   R-squared:                       0.367
# Model:                            OLS   Adj. R-squared:                  0.254
# Method:                 Least Squares   F-statistic:                     3.248
# Date:                Tue, 09 Apr 2019   Prob (F-statistic):           0.000294
# Time:                        18:40:36   Log-Likelihood:                 5.8380
# No. Observations:                 100   AIC:                             20.32
# Df Residuals:                      84   BIC:                             62.01
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0709      0.317      3.381      0.001       0.441       1.701
# ...

# %% [markdown]
# ### Question 8
# ##### Question
# Redo the fit in question 6 leaving out the two lagged unemployment rates. If the fit materially worse? How does it differ?

# %%
import statsmodels.api as sm
data3 = pd.read_excel('Phillips.xls',sheetname = 'Regression1',header=0)
varlist3 = data3.columns.values
m = data3[varlist3[0]]
n=data3[varlist3[1:14]]
n=sm.add_constant(n)
model3 = sm.OLS(m,n).fit() 
predictions3 = model3.predict(n)
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      t   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.800
# Method:                 Least Squares   F-statistic:                     42.26
# Date:                Tue, 09 Apr 2019   Prob (F-statistic):           1.04e-38
# Time:                        18:21:56   Log-Likelihood:                -16.042
# No. Observations:                 135   AIC:                             60.08
# Df Residuals:                     121   BIC:                             100.8
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0744      0.045      1.651      0.101      -0.015       0.164
# ...

# %% [markdown]
# ### Question 9
# Use the actual core inflation rates and fitted values from question 6 to recreate the author's figure 2. How well does your graph match his? Does it support his contention that the model fit is good, and getting better as the period goes on? Look closely to see if the fit lines up with the actual in time, or if it is consistently one month late in moves?

# %%
data3['Fitted']=model.predict()

# %%
plt.ylim(-1,4)
# plt.axhline(y=0, color='black',linestyle='-')
t = np.linspace(1960,1983,len(data3))
plt.plot(t,data3['Fitted'],dashes=[3, 1],label='Fitted Value')
plt.plot(t,data3['t'],label = 'True Value')
plt.title('Total Compensation vs. Unemployment gap')
plt.legend()
plt.show()

# %% [markdown]
# ### Question 10
# ##### Question
# Reproduce figure 2 for the period from 1994Q1 to the present. That is, you're still using the coefficients from question 5, based on data from 1960Q2 to 1993Q4, but applying the model to data from 1994Q1 to 2017Q2. Answer the same questions as in question 8. What does this tell you about the author's model?

# %%
data4['Fitted2']=model.predict(q)
plt.ylim(-0.5,2)
# plt.axhline(y=0, color='black',linestyle='-')
t2 = np.linspace(1994,2018,len(data5))
plt.plot(t2,data4['Fitted2'],dashes=[3, 1],label='Fitted Value')
plt.plot(t2,data4['t'],label = 'True Value')
plt.title('Total Compensation vs. Unemployment gap')
plt.legend()
plt.show()

# %% [markdown]
# ### Question 11
# ##### Question
# What is the regression Beta of actual values on fitted values for the in-sample period from 1960Q2 to 1993Q4? How about for the out-of-sample period 1994Q1 to 2017Q2? Answer the same questions for the model without the two lagged unemployment rates. What does this suggest about the value of the lagged unemployment rates in predicting inflation?
